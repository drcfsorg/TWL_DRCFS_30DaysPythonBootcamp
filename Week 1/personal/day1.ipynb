# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello dear")
# Out:
# hello dear

# %%
x = input('what is your name')
print('my name is ', x)
# Out:
# my name is  binayak

# %%
print(1 !=2)
print(type(True))
# Out:
# True
# <class 'bool'>

# %%
age = input('what is age')
# age = float(age)
print(age , 10)
# Out:
# 8 10
